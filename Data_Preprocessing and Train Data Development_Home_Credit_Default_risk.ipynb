# %% [markdown]
# ## Data_Preprocessing and Train Data Development

# %% [markdown]
# This section aims to make a ready to model dataset by encoding all the categorical features and drop any collinear features and scaling the data if applicable.

# %% [markdown]
# ## Importing Basic Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import scipy

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 1) Application Train

# %% [markdown]
# ##### Dummy variables for categorical features

# %%
df=pd.read_csv('Final_data/df_application_train_without_null_without_dummies.csv')
df.info(verbose=True, null_counts=True)

# %%
df[['FLAG_MOBIL',
 'FLAG_EMP_PHONE',
 'FLAG_WORK_PHONE',
 'FLAG_CONT_MOBILE',
 'FLAG_PHONE',
 'FLAG_EMAIL']]=df[['FLAG_MOBIL',
 'FLAG_EMP_PHONE',
 'FLAG_WORK_PHONE',
 'FLAG_CONT_MOBILE',
 'FLAG_PHONE',
 'FLAG_EMAIL']].astype('object')

# %%
df[['REGION_RATING_CLIENT',
 'REGION_RATING_CLIENT_W_CITY',
 'REG_REGION_NOT_LIVE_REGION',
 'REG_REGION_NOT_WORK_REGION',
 'LIVE_REGION_NOT_WORK_REGION',
 'REG_CITY_NOT_LIVE_CITY',
 'REG_CITY_NOT_WORK_CITY',
 'LIVE_CITY_NOT_WORK_CITY' ]]=df[['REGION_RATING_CLIENT',
 'REGION_RATING_CLIENT_W_CITY','REG_REGION_NOT_LIVE_REGION',
 'REG_REGION_NOT_WORK_REGION',
 'LIVE_REGION_NOT_WORK_REGION','REG_CITY_NOT_LIVE_CITY',
 'REG_CITY_NOT_WORK_CITY',
 'LIVE_CITY_NOT_WORK_CITY' ]].astype('object')

# %%
df[['FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3',
 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5',
 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7',
 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9',
 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11',
 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13',
 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15',
 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17',
 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19',
 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21']]=df[['FLAG_DOCUMENT_2',
 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4',
 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6',
 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8',
 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10',
 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12',
 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14',
 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16',
 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18',
 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21']].astype('object')

# %%
cat=df.select_dtypes('object').columns
len(cat)
# Out:
# 52

# %%
dummies=pd.get_dummies(df[cat],drop_first=True)
df=pd.concat([df,dummies], axis=1)
df.drop(cat, inplace=True, axis=1)
df.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307216 entries, 0 to 307215
# Data columns (total 264 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   SK_ID_CURR                                307216 non-null  int64
#  1   TARGET                                    307216 non-null  int64
#  2   AMT_INCOME_TOTAL                          307216 non-null  float64
#  3   AMT_CREDIT                                307216 non-null  float64
#  4   AMT_ANNUITY                               307216 non-null  float64
#  5   AMT_GOODS_PRICE                           307216 non-null  float64
#  6   REGION_POPULATION_RELATIVE                307216 non-null  float64
#  7   DAYS_BIRTH                                307216 non-null  int64
#  8   DAYS_EMPLOYED                             307216 non-null  int64
#  9   DAYS_REGISTRATION                         307216 non-null  float64
# ...

# %%
# correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.98
to_drop = [column for column in upper.columns if any(upper[column] > 0.98)]

len(to_drop)
# Out:
# 49

# %%
df=df.drop(df[to_drop], axis=1)
len(df.columns)
# Out:
# 215

# %%
df.to_csv('Final_data/final_application_train_corr_0.98.csv', index=False)

# %%
df.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307216 entries, 0 to 307215
# Data columns (total 215 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   SK_ID_CURR                                307216 non-null  int64
#  1   TARGET                                    307216 non-null  int64
#  2   AMT_INCOME_TOTAL                          307216 non-null  float64
#  3   AMT_CREDIT                                307216 non-null  float64
#  4   AMT_ANNUITY                               307216 non-null  float64
#  5   REGION_POPULATION_RELATIVE                307216 non-null  float64
#  6   DAYS_BIRTH                                307216 non-null  int64
#  7   DAYS_EMPLOYED                             307216 non-null  int64
#  8   DAYS_REGISTRATION                         307216 non-null  float64
#  9   DAYS_ID_PUBLISH                           307216 non-null  int64
# ...

# %% [markdown]
# ### Final df

# %%
df=pd.read_csv('Final_data/cleaned_df_without_null_without_dummies.csv')
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307216 entries, 0 to 307215
# Data columns (total 485 columns):
#  #   Column                                                       Non-Null Count   Dtype
# ---  ------                                                       --------------   -----
#  0   SK_ID_CURR                                                   307216 non-null  int64
#  1   TARGET                                                       307216 non-null  int64
#  2   NAME_CONTRACT_TYPE                                           307216 non-null  object
#  3   CODE_GENDER                                                  307216 non-null  object
#  4   FLAG_OWN_CAR                                                 307216 non-null  object
#  5   FLAG_OWN_REALTY                                              307216 non-null  object
#  6   CNT_CHILDREN                                                 307216 non-null  object
# ...

# %%
cat=df.select_dtypes('object').columns
len(cat)
# Out:
# 59

# %%
dummies=pd.get_dummies(df[cat],drop_first=True)
df=pd.concat([df,dummies], axis=1)
df.drop(cat, inplace=True, axis=1)
df.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307216 entries, 0 to 307215
# Data columns (total 640 columns):
#  #   Column                                                          Non-Null Count   Dtype
# ---  ------                                                          --------------   -----
#  0   SK_ID_CURR                                                      307216 non-null  int64
#  1   TARGET                                                          307216 non-null  int64
#  2   AMT_INCOME_TOTAL                                                307216 non-null  float64
#  3   AMT_CREDIT                                                      307216 non-null  float64
#  4   AMT_ANNUITY                                                     307216 non-null  float64
#  5   AMT_GOODS_PRICE                                                 307216 non-null  float64
#  6   REGION_POPULATION_RELATIVE                                      307216 non-null  float64
# ...

# %%
# correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.98
to_drop = [column for column in upper.columns if any(upper[column] > 0.98)]

len(to_drop)
# Out:
# 115

# %%
df=df.drop(df[to_drop], axis=1)
len(df.columns)
# Out:
# 528

# %%
df1.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307216 entries, 0 to 307215
# Data columns (total 643 columns):
#  #   Column                                                          Non-Null Count   Dtype
# ---  ------                                                          --------------   -----
#  0   SK_ID_CURR                                                      307216 non-null  int64
#  1   TARGET                                                          307216 non-null  int64
#  2   AMT_INCOME_TOTAL                                                307216 non-null  float64
#  3   AMT_CREDIT                                                      307216 non-null  float64
#  4   AMT_ANNUITY                                                     307216 non-null  float64
#  5   AMT_GOODS_PRICE                                                 307216 non-null  float64
#  6   REGION_POPULATION_RELATIVE                                      307216 non-null  float64
# ...

# %%
df1=df.fillna(value=0)
df1.to_csv('Final_data/final_df.csv', index=False)

# %%
df.to_csv('Final_data/final_df_with_null_with_dummies.csv', index=False)

# %% [markdown]
# ### Test train splitting and scaling

# %%
# Variable separation: Features and Target
X=df.drop(['TARGET','SK_ID_CURR'], axis=1).values
y=df['TARGET'].values

# Train-Test Splitting
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# Data Scaling using MinMax Scalar
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)
